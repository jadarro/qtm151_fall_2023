# %% [markdown]
# # <span style="color:darkblue"> Lecture 13 - Aggregating Data </span>
#
# <font size = "5">
#
# In the previous class we covered
#
# - Missing values
# - The basics of data cleaning
#
# This class we will talk about
# - Computing aggregate statistics by group
# - Introduction to merging

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
# Key libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# <font size = "5">
#
# Read dataset on car racing circuits
#
# - https://en.wikipedia.org/wiki/Formula_One <br>
# - [See Data Source](https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020)

# %%
results = pd.read_csv("data_raw/results.csv")

# %% [markdown]
# <font size = "5">
#
# The dataset "codebook" is a table with ...
#
# - Key column information
# - Main things:  Field, Type, Key, and Description
#
# <img src="figures/codebook_races.png" alt="drawing" width="600"/>

# %%
# The codebook contains basic about the columns
# "Field" is the name given to the name of the column
# "Type"  is the variable type:
#         integer (int)
#         string (varchar - "variable character")
#         float (float)
#         The number in parenthesis is the maximum number of characters/digits
#         For most purposes we can ignore the numbers in parentheses.
# "Key" denotes whether this is the primary key "PRI" (also known as the identifier)
#         This is a column with unique values, that uniquely identifies each row
# "Description" contains a label with the content of the variable

# %% [markdown]
# <font size = "5">
#
# Get column names + types
#
# - Do types match the codebook?
# - If not the data may need to be cleaned

# %%
# This code displays column types
# "int" or "float" objects are numneric
# "object" typically denotes strings
# If a column that's supposed to be "numeric" but appears as "object"
# then it needs to be cleaned and converted to numeric 

results.dtypes
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - How many rows does the dataset have?
# - How many unique values are there for the columns <br>
# $\qquad$ "resultId"? <br>
# $\qquad$ "raceId"? <br>
# $\qquad$ "driverId"? <br>
#
# HINT: Use the "len()" and the "pd.unique()" functions

# %%
# Write your own code here
len(results)
# Out:
# 25840

# %%
results["resultId"].unique()
len(results["resultId"].unique())
# Out:
# 25840

# %%
len(results['raceId'].unique())
# Out:
# 1079

# %% [markdown]
# # <span style="color:darkblue"> II. Aggregate + groupby  </span>

# %% [markdown]
# <font size = "5">
#
# Splitting code into multiple lines
#
# - Makes it easier to read
# - Simply wrap the code in round parentheses "()"

# %%
# The following code computes descriptive statistics for points 
# Wrapping the code in parentheses "()" allows you to split it into multiple 
# lines. It's considered good practice to make each line less than 80 characters
# This makes it easier to scroll up and down without going sideways.

descriptives_singleline = results["points"].describe()
descriptives_singleline
# Out:
# count    25840.000000
# mean         1.877053
# std          4.169849
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max         50.000000
# Name: points, dtype: float64

# %%
descriptives_multiline = (results["points"]
                          .describe())
descriptives_multiline
# Out:
# count    25840.000000
# mean         1.877053
# std          4.169849
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max         50.000000
# Name: points, dtype: float64

# %% [markdown]
# <font size = "5">
#
# Aggregate statistics

# %%
# The ".agg()" subfunction computes aggregate statistics
# The syntax is ("column_name","function_name")
# The first argument is the column name
# The second argument is the function_name
# The command works with single quotations '...' or double "..."

results_agg = results.agg(mean_points = ('points','mean'),
                          sd_points =   ('points','std'),
                          min_points =  ('points','min'),
                          max_points =  ('points','max'),
                          count_obs   = ('points',len))

display(results_agg)
# Out:
#                    points
# mean_points      1.877053
# sd_points        4.169849
# min_points       0.000000
# max_points      50.000000
# count_obs    25840.000000

# %% [markdown]
# <font size = "5" >
#
# Groupby + Aggregate statistics
#
# <img src="figures/agg.png" alt="drawing" width="400"/>

# %%
# In this cases drivers engage in multiple car races
# We can compute the aggregate statistics for each specific driver across
# multiple car races

drivers_agg = (results.groupby("driverId")
                      .agg(mean_points = ('points','mean'),
                           sd_points =   ('points','std'),
                           min_points =  ('points','min'),
                           max_points =  ('points','max'),
                           count_obs   = ('points',len)))

drivers_agg
# Out:
#           mean_points  sd_points  min_points  max_points  count_obs
# driverId
# 1           14.182258   9.224098         0.0        50.0        310
# 2            1.407609   2.372923         0.0        15.0        184
# 3            7.740291   8.672456         0.0        25.0        206
# 4            5.756983   6.330721         0.0        25.0        358
# 5            0.937500   1.969503         0.0        10.0        112
# ...               ...        ...         ...         ...        ...
# 852          1.000000   2.477808         0.0        12.0         44
# 853          0.000000   0.000000         0.0         0.0         22
# 854          0.272727   1.335798         0.0         8.0         44
# 855          0.272727   0.882735         0.0         4.0         22
# 856          2.000000        NaN         2.0         2.0          1
#
# [855 rows x 5 columns]

# %%
results.loc[results['driverId'] == 1, ['points']].mean()
# Out:
# points    14.182258
# dtype: float64

# %% [markdown]
# <font size = "5" >
# Groupby + Aggregate statistics (multigroup)

# %%
# We can aggregate statistics from multiple columns by
# entering a list of column names in "groupby"
# In this case "constructor" in this case denotes the team 
# The following computes aggregate point stats for each (team, race) combination

teamrace_agg = (results.groupby(["raceId","constructorId"])
                       .agg(mean_points = ('points','mean'),
                            sd_points =   ('points','std'),
                            min_points =  ('points','min'),
                            max_points =  ('points','max'),
                            count_obs   = ('points',len)))

len(teamrace_agg)
teamrace_agg
# Out:
#                       mean_points  sd_points  min_points  max_points  \
# raceId constructorId
# 1      1                      0.0   0.000000         0.0         0.0
#        2                      0.0   0.000000         0.0         0.0
#        3                      1.5   2.121320         0.0         3.0
#        4                      2.0   2.828427         0.0         4.0
#        5                      1.5   0.707107         1.0         2.0
# ...                           ...        ...         ...         ...
# 1096   117                    2.5   2.121320         1.0         4.0
#        131                    5.0   7.071068         0.0        10.0
#        210                    0.0   0.000000         0.0         0.0
#        213                    0.0   0.000000         0.0         0.0
#        214                    3.0   4.242641         0.0         6.0
#
#                       count_obs
# raceId constructorId
# 1      1                      2
#        2                      2
#        3                      2
#        4                      2
#        5                      2
# ...                         ...
# 1096   117                    2
#        131                    2
#        210                    2
#        213                    2
#        214                    2
#
# [12568 rows x 5 columns]

# %%
results.query("raceId >= 500").groupby(["raceId","constructorId"]).agg(mean_points = ("points","mean"))
# Out:
#                       mean_points
# raceId constructorId
# 500    1                      0.0
#        3                      1.0
#        4                      4.5
#        6                      0.0
#        21                     0.5
# ...                           ...
# 1096   117                    2.5
#        131                    5.0
#        210                    0.0
#        213                    0.0
#        214                    3.0
#
# [6055 rows x 1 columns]

# %% [markdown]
# <font size = "5">
#
# Filtering + Grouping + Aggregating: <br>
#
# ```python
# .query().groupby().agg()
# ```
#
# - This sequential syntax is known as "chaining"

# %%
# The following gets a subset of the data using .query()
# In this case we subset the data before computing aggregate statistics
# Note: "filtering" is often the word used to obtain a subset

teamrace_agg = (results.query("raceId >= 500")
                       .groupby(["raceId","constructorId"])
                        .agg(mean_points = ('points','mean'),
                             sd_points =   ('points','std'),
                             min_points =  ('points','min'),
                             max_points =  ('points','max'),
                             count_obs   = ('points',len)))
teamrace_agg
# Out:
#                       mean_points  sd_points  min_points  max_points  \
# raceId constructorId
# 500    1                      0.0   0.000000         0.0         0.0
#        3                      1.0   1.414214         0.0         2.0
#        4                      4.5   6.363961         0.0         9.0
#        6                      0.0   0.000000         0.0         0.0
#        21                     0.5   0.707107         0.0         1.0
# ...                           ...        ...         ...         ...
# 1096   117                    2.5   2.121320         1.0         4.0
#        131                    5.0   7.071068         0.0        10.0
#        210                    0.0   0.000000         0.0         0.0
#        213                    0.0   0.000000         0.0         0.0
#        214                    3.0   4.242641         0.0         6.0
#
#                       count_obs
# raceId constructorId
# 500    1                      2
#        3                      2
#        4                      2
#        6                      2
#        21                     2
# ...                         ...
# 1096   117                    2
#        131                    2
#        210                    2
#        213                    2
#        214                    2
#
# [6055 rows x 5 columns]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Create a new dataset by chaining  <br>
# groups by "raceId" then computes the <br>
# aggregate statistics: "points" average <br> and "laps" average

# %%
# Write your own code
raceId_points_laps = (results.groupby(["raceId"])
                      .agg(points_avg = ("points","mean"),
                           laps_avg = ("laps","mean")
                      ))
raceId_points_laps
# Out:
#         points_avg  laps_avg
# raceId
# 1            1.950     50.25
# 2            0.975     27.70
# 3            1.950     51.15
# 4            1.950     56.25
# 5            1.950     47.10
# ...            ...       ...
# 1092         5.050     25.20
# 1093         5.100     49.50
# 1094         5.100     68.90
# 1095         5.100     62.80
# 1096         5.100     55.85
#
# [1079 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Create a new dataset by chaining <br>
# groups by "constructorId" (the team) then <br>
# computes the average number of "points"
# - Add a chain ".sort_values(...,ascending = False)" <br>
# to sort by team points in desceding order

# %%
# Write your own code
constructor_agg = (results.groupby("constructorId")
                   .agg(avg_points = ("points","mean")).sort_values(by="avg_points",ascending = False))
constructor_agg
# Out:
#                avg_points
# constructorId
# 131             12.363643
# 9                9.117816
# 23               5.058824
# 208              4.584416
# 6                4.317968
# ...                   ...
# 76               0.000000
# 77               0.000000
# 78               0.000000
# 130              0.000000
# 112              0.000000
#
# [210 rows x 1 columns]

# %% [markdown]
# # <span style="color:darkblue"> III. Relative statistics within group </span>

# %% [markdown]
# <font size = "5">
#
# Merging
#
# <img src="figures/merge_stats.png" alt="drawing" width="600"/>

# %%
# This command merges the "aggregate" information in "driver_agg" into
# "results" as shown in the figure
# The merging variable "on" is determined by "driverId", which is a column
# that is common to both datasets
# "how = left" indicates that the left dataset is the baseline
#
# Note: For this method to work well "driverId" needs to contain unique alues
# in "drivers_agg". If not you may need to clean the data beforehand

results_merge = pd.merge(results,
                         drivers_agg,
                         on = "driverId",
                         how = "left")
results_merge
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...  fastestLap rank  \
# 0                1              1    10.0  ...          39    2
# 1                2              2     8.0  ...          41    3
# 2                3              3     6.0  ...          41    5
# 3                4              4     5.0  ...          58    7
# 4                5              5     4.0  ...          43    1
# ...            ...            ...     ...  ...         ...  ...
# 25835           16             16     0.0  ...          39   12
# 25836           17             17     0.0  ...          40   20
# 25837           18             18     0.0  ...          42   11
# 25838           19             19     0.0  ...          45   14
# 25839            R             20     0.0  ...          24   17
#
#       fastestLapTime fastestLapSpeed statusId mean_points sd_points  \
# 0           1:27.452         218.300        1   14.182258  9.224098
# 1           1:27.739         217.586        1    1.407609  2.372923
# 2           1:28.090         216.719        1    7.740291  8.672456
# 3           1:28.603         215.464        1    5.756983  6.330721
# 4           1:27.418         218.385        1    0.937500  1.969503
# ...              ...             ...      ...         ...       ...
# 25835       1:29.833         211.632       11    0.272727  1.335798
# 25836       1:31.158         208.556       11    1.260563  2.771894
# 25837       1:29.788         211.738        9   14.182258  9.224098
# 25838       1:30.309         210.517      130    0.147541  0.813143
# 25839       1:30.579         209.889       47    5.756983  6.330721
#
#        min_points  max_points  count_obs
# 0             0.0        50.0        310
# 1             0.0        15.0        184
# 2             0.0        25.0        206
# 3             0.0        25.0        358
# 4             0.0        10.0        112
# ...           ...         ...        ...
# 25835         0.0         8.0         44
# 25836         0.0        18.0        142
# 25837         0.0        50.0        310
# 25838         0.0         6.0         61
# 25839         0.0        25.0        358
#
# [25840 rows x 23 columns]

# %% [markdown]
# <font size = "5">
#
# Check out another approach to compute <br>
# aggregate statistics using ``` .transform() ```<br>
#  in the optional lecture!

# %%
two_col = results[["driverId","points"]]
# calculating mean (with syntax 1)
print(results.groupby("driverId")["points"].mean())
# calculating mena with syntax 2
print(results.groupby("driverId")["points"].transform("mean"))
# Out:
# driverId
# 1      14.182258
# 2       1.407609
# 3       7.740291
# 4       5.756983
# 5       0.937500
#          ...
# 852     1.000000
# 853     0.000000
# 854     0.272727
# 855     0.272727
# 856     2.000000
# Name: points, Length: 855, dtype: float64
# 0        14.182258
# 1         1.407609
# 2         7.740291
# 3         5.756983
# 4         0.937500
#            ...
# 25835     0.272727
# 25836     1.260563
# 25837    14.182258
# 25838     0.147541
# 25839     5.756983
# Name: points, Length: 25840, dtype: float64

# %%
results.groupby("driverId")["points"].transform('std')
# Out:
# 0        9.224098
# 1        2.372923
# 2        8.672456
# 3        6.330721
# 4        1.969503
#            ...
# 25835    1.335798
# 25836    2.771894
# 25837    9.224098
# 25838    0.813143
# 25839    6.330721
# Name: points, Length: 25840, dtype: float64

# %%
results["points"]
# Out:
# 0        10.0
# 1         8.0
# 2         6.0
# 3         5.0
# 4         4.0
#          ...
# 25835     0.0
# 25836     0.0
# 25837     0.0
# 25838     0.0
# 25839     0.0
# Name: points, Length: 25840, dtype: float64

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Compute a scatter plot with ...
# - "points" (y-axis) vs "mean_points" (x-axis)
#
# Note: This plots tells you how much a driver's <br>
# performance on individual races deviates from <br>
# their overall average

# %%
# Write your own code
# this questions is not worded correctly. It's impossible to do without running into problems 
raceId_points_avgpoints = (results.groupby("raceId").agg
                           (mean_points = ("points","mean")))
results_points_merge = pd.merge(
    results,
    raceId_points_avgpoints,
    on = "raceId",
    how="left"
)
results_points_merge

# scatterplot 
plt.scatter(x = results_points_merge["raceId"], y = results_points_merge["points"])
plt.scatter(x = raceId_points_avgpoints["raceId"], y = raceId_points_avgpoints["mean_points"])
plt.legend(labels = ["mean points","points"],
           title = "points vs. mean points")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/qtm151/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/qtm151/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/qtm151/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'raceId'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb Cell 41 line 1
#      <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=11'>12</a> # scatterplot
#      <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=12'>13</a> plt.scatter(x = results_points_merge["raceId"], y = results_points_merge["points"])
# ---> <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=13'>14</a> plt.scatter(x = raceId_points_avgpoints["raceId"], y = raceId_points_avgpoints["mean_points"])
#      <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=14'>15</a> plt.legend(labels = ["mean points","points"],
#      <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=15'>16</a>            title = "points vs. mean points")
#      <a href='vscode-notebook-cell:/Users/jareddarrow/Desktop/QTM151/qtm151_fall_2023/lecture_13/personal_lecture_13.ipynb#X55sZmlsZQ%3D%3D?line=16'>17</a> plt.show()
#
# File ~/anaconda3/envs/qtm151/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/qtm151/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'raceId'

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Merge the "teamrace_agg" data into "results"
# - This time use the option:
#
# $\qquad$ ```on = ["raceId","constructorId"]```

# %%
# Write your own code
pd.merge(results,
         teamrace_agg,
         on = ["raceId","constructorId"],
         how = "left")
# this merges the two data sets based on the items: race id and constructor id
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...  fastestLap rank  \
# 0                1              1    10.0  ...          39    2
# 1                2              2     8.0  ...          41    3
# 2                3              3     6.0  ...          41    5
# 3                4              4     5.0  ...          58    7
# 4                5              5     4.0  ...          43    1
# ...            ...            ...     ...  ...         ...  ...
# 25835           16             16     0.0  ...          39   12
# 25836           17             17     0.0  ...          40   20
# 25837           18             18     0.0  ...          42   11
# 25838           19             19     0.0  ...          45   14
# 25839            R             20     0.0  ...          24   17
#
#       fastestLapTime fastestLapSpeed statusId mean_points sd_points  \
# 0           1:27.452         218.300        1         NaN       NaN
# 1           1:27.739         217.586        1         NaN       NaN
# 2           1:28.090         216.719        1         NaN       NaN
# 3           1:28.603         215.464        1         NaN       NaN
# 4           1:27.418         218.385        1         NaN       NaN
# ...              ...             ...      ...         ...       ...
# 25835       1:29.833         211.632       11         0.0  0.000000
# 25836       1:31.158         208.556       11         0.0  0.000000
# 25837       1:29.788         211.738        9         5.0  7.071068
# 25838       1:30.309         210.517      130         0.0  0.000000
# 25839       1:30.579         209.889       47         3.0  4.242641
#
#        min_points  max_points  count_obs
# 0             NaN         NaN        NaN
# 1             NaN         NaN        NaN
# 2             NaN         NaN        NaN
# 3             NaN         NaN        NaN
# 4             NaN         NaN        NaN
# ...           ...         ...        ...
# 25835         0.0         0.0        2.0
# 25836         0.0         0.0        2.0
# 25837         0.0        10.0        2.0
# 25838         0.0         0.0        2.0
# 25839         0.0         6.0        2.0
#
# [25840 rows x 23 columns]
